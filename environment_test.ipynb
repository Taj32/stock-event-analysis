# %%
# Cell 1: Test imports
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime
print("All imports successful")
# Out:
# ✓ All imports successful

# %%
# Cell 2: Test yfinance
# NOTE: Too Many Requests issue. Probably need to find other APIS.
import yfinance as yf

# Create a Ticker object for Microsoft (MSFT)
microsoft = yf.Ticker("MSFT")

# Get company information
info = microsoft.info

# Print a specific piece of information, e.g., the company's long description
print(f"Company Name: {info['shortName']}")
print(f"Sector: {info['sector']}")
print(f"Industry: {info['industry']}")
print(f"Description: {info['longBusinessSummary']}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[22], line 8
#       5 microsoft = yf.Ticker("MSFT")
#       7 # Get company information
# ----> 8 info = microsoft.info
#      10 # Print a specific piece of information, e.g., the company's long description
#      11 print(f"Company Name: {info['shortName']}")
#
# File d:\Python Projects\stock-event-analysis\.venv\Lib\site-packages\yfinance\ticker.py:142, in info(self)
#     137 @property
#     138 def insider_roster_holders(self) -> _pd.DataFrame:
#     139     return self.get_insider_roster_holders()
#     141 @property
# --> 142 def dividends(self) -> _pd.Series:
#     143     return self.get_dividends()
#     145 @property
#     146 def capital_gains(self) -> _pd.Series:
#
# File d:\Python Projects\stock-event-analysis\.venv\Lib\site-packages\yfinance\base.py:1736, in get_info(self, proxy)
# ...

# %%
# Cell 3: Test pandas
df = pd.DataFrame({'test': [1, 2, 3]})
print("✓ Pandas working")
print(df)
# Out:
# ✓ Pandas working
#    test
# 0     1
# 1     2
# 2     3
